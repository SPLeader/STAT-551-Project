# %% [markdown]
# # AQI Data Visualization (Python)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
# Out:
# d:\ProgramFiles\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
aqi_ozone = pd.read_csv("Project Data/Combined/aqi_ozone_all_years.csv")
aqi_ozone["Date"] = pd.to_datetime(aqi_ozone["Date"])
aqi_ozone["Month"] = aqi_ozone["Date"].dt.month

# %%
aqi_ozone.head()
# Out:
#      State     County       Date  AQI AQI_cat        co     ozone        no2  \
# 0  Alabama  Jefferson 2021-02-02   38    Good  0.177249  0.037647   4.016667
# 1  Alabama  Jefferson 2021-02-07   31    Good  0.181250  0.022941   4.600000
# 2  Alabama  Jefferson 2021-03-01   29    Good  0.152017  0.025088   5.604166
# 3  Alabama  Jefferson 2021-03-02   28    Good  0.218221  0.021257   7.904762
# 4  Alabama  Jefferson 2021-03-03   44    Good  0.277886  0.025270  13.313492
#
#         so2      wind       temp      humid    pressure        no  Month
# 0  0.145536  3.741667  37.131250  51.354167  997.543750  0.496905      2
# 1  0.153125  2.341667  40.116667  82.104166  995.295833  0.538889      2
# 2  0.292857  5.868750  55.916667  83.833333  997.087500  1.395635      3
# 3  0.329464  4.879167  44.135417  71.479166  998.847916  1.148333      3
# 4  0.259673  3.845833  49.581250  60.208334  996.454167  6.002778      3

# %%
aqi_ozone["Date"].dt.month.value_counts()
# Out:
# 5     1529
# 6     1414
# 4     1385
# 3     1291
# 7      876
# 9      831
# 8      767
# 2      707
# 1      625
# 10     489
# 12     269
# 11     250
# Name: Date, dtype: int64

# %%
aqi_ozone[["State"]].value_counts()
# Out:
# State
# California              1408
# Maryland                 871
# Texas                    824
# Arizona                  824
# Vermont                  456
# Wyoming                  411
# North Carolina           386
# Idaho                    365
# Rhode Island             352
# Louisiana                333
# North Dakota             321
# Tennessee                301
# Michigan                 289
# Nevada                   277
# Virginia                 274
# Washington               238
# Ohio                     237
# District Of Columbia     215
# Connecticut              214
# Pennsylvania             210
# Massachusetts            204
# Georgia                  194
# Illinois                 193
# New Hampshire            188
# New Mexico               176
# Missouri                 168
# New Jersey               147
# Alabama                  122
# Kentucky                 113
# Indiana                   83
# New York                  29
# Oregon                    10
# dtype: int64

# %%
aqi_ozone.boxplot(column = "AQI", by = "Month")
# Out:
# <AxesSubplot:title={'center':'AQI'}, xlabel='Month'>

# %%
aqi_ozone["ozone"].corr(aqi_ozone["AQI"])
# Out:
# 0.6099995087855692

# %%
plt.scatter(x = aqi_ozone["ozone"], y = aqi_ozone["AQI"], c = "Black")

# %%
aqi_ozone["humid"].plot.hist(color = "Gray")
# Out:
# <AxesSubplot:ylabel='Frequency'>
